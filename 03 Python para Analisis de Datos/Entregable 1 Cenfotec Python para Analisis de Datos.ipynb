# %%
import pandas as pd

# %%
df = pd.read_csv("/content/penguins.csv")

# %%
df.head(12)
# Out:
#     Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0            1  Adelie  Torgersen            39.1           18.7
# 1            2  Adelie  Torgersen            39.5           17.4
# 2            3  Adelie  Torgersen            40.3           18.0
# 3            4  Adelie  Torgersen             NaN            NaN
# 4            5  Adelie  Torgersen            36.7           19.3
# 5            6  Adelie  Torgersen            39.3           20.6
# 6            7  Adelie  Torgersen            38.9           17.8
# 7            8  Adelie  Torgersen            39.2           19.6
# 8            9  Adelie  Torgersen            34.1           18.1
# 9           10  Adelie  Torgersen            42.0           20.2
# 10          11  Adelie  Torgersen            37.8           17.1
# 11          12  Adelie  Torgersen            37.8           17.3
#
#     flipper_length_mm  body_mass_g     sex  year
# 0               181.0       3750.0    male  2007
# ...

# %%
#Estadisticas basicas de las variables numericas

df.describe()
# Out:
#        Unnamed: 0  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
#Mostrar tipo de datos

df.info()

#Conteo rapido: (float64/int64) y Caterogicas (object)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
#Cuantas filas y columnas tengo.

df.shape
# Out:
# (344, 9)

# %%
#Nuevo Dataframe

df_nuevo = df[['species','bill_length_mm','bill_depth_mm','body_mass_g','sex']]
df_nuevo.head()
# Out:
#   species  bill_length_mm  bill_depth_mm  body_mass_g     sex
# 0  Adelie            39.1           18.7       3750.0    male
# 1  Adelie            39.5           17.4       3800.0  female
# 2  Adelie            40.3           18.0       3250.0  female
# 3  Adelie             NaN            NaN          NaN     NaN
# 4  Adelie            36.7           19.3       3450.0  female

# %%
#Data Frame con variables seleccionadas

df_ordenado =df.sort_values(by='body_mass_g',ascending=True)
df_ordenado.head()
# Out:
#      Unnamed: 0    species  island  bill_length_mm  bill_depth_mm  \
# 314         315  Chinstrap   Dream            46.9           16.6
# 58           59     Adelie  Biscoe            36.5           16.6
# 64           65     Adelie  Biscoe            36.4           17.1
# 54           55     Adelie  Biscoe            34.5           18.1
# 98           99     Adelie   Dream            33.1           16.1
#
#      flipper_length_mm  body_mass_g     sex  year
# 314              192.0       2700.0  female  2008
# 58               181.0       2850.0  female  2008
# 64               184.0       2850.0  female  2008
# 54               187.0       2900.0  female  2008
# 98               178.0       2900.0  female  2008

# %%
#Filtro Female >3750

filtro_h = df[(df['sex']=='female') & (df['body_mass_g']>3750)]
filtro_h
# Out:
#      Unnamed: 0    species     island  bill_length_mm  bill_depth_mm  \
# 1             2     Adelie  Torgersen            39.5           17.4
# 22           23     Adelie     Biscoe            35.9           19.2
# 25           26     Adelie     Biscoe            35.3           18.9
# 82           83     Adelie  Torgersen            36.7           18.8
# 110         111     Adelie     Biscoe            38.1           16.5
# ..          ...        ...        ...             ...            ...
# 284         285  Chinstrap      Dream            46.0           18.9
# 286         287  Chinstrap      Dream            46.6           17.8
# 311         312  Chinstrap      Dream            47.5           16.8
# 312         313  Chinstrap      Dream            47.6           18.3
# 343         344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 1                186.0       3800.0  female  2007
# ...

# %%
#Filtro especie Gentoo

filtro_i = df[(df['species']=='Gentoo')&(df['bill_depth_mm']<18.1)]
filtro_i
# Out:
#      Unnamed: 0 species  island  bill_length_mm  bill_depth_mm  \
# 152         153  Gentoo  Biscoe            46.1           13.2
# 153         154  Gentoo  Biscoe            50.0           16.3
# 154         155  Gentoo  Biscoe            48.7           14.1
# 155         156  Gentoo  Biscoe            50.0           15.2
# 156         157  Gentoo  Biscoe            47.6           14.5
# ..          ...     ...     ...             ...            ...
# 270         271  Gentoo  Biscoe            47.2           13.7
# 272         273  Gentoo  Biscoe            46.8           14.3
# 273         274  Gentoo  Biscoe            50.4           15.7
# 274         275  Gentoo  Biscoe            45.2           14.8
# 275         276  Gentoo  Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex  year
# 152              211.0       4500.0  female  2007
# 153              230.0       5700.0    male  2007
# 154              210.0       4450.0  female  2007
# ...

# %%
#Columna de multiplicacion

df['multiplicacion_pico'] =df['bill_length_mm']* df['bill_depth_mm']

#Visualizar el resultado
df.head()
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           1  Adelie  Torgersen            39.1           18.7
# 1           2  Adelie  Torgersen            39.5           17.4
# 2           3  Adelie  Torgersen            40.3           18.0
# 3           4  Adelie  Torgersen             NaN            NaN
# 4           5  Adelie  Torgersen            36.7           19.3
#
#    flipper_length_mm  body_mass_g     sex  year  multiplicacion_pico
# 0              181.0       3750.0    male  2007               731.17
# 1              186.0       3800.0  female  2007               687.30
# 2              195.0       3250.0  female  2007               725.40
# 3                NaN          NaN     NaN  2007                  NaN
# 4              193.0       3450.0  female  2007               708.31
